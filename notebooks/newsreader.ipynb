# %%
from langchain.document_loaders import TextLoader

# %%
loader = TextLoader("data/nvidia.txt", encoding="utf-8")
data = loader.load()

# %%
data[0].page_content
# Out:
# "The stock of NVIDIA Corp (NASDAQ:NVDA) experienced a daily loss of -3.56% and a 3-month gain of 32.35%. With an Earnings Per Share (EPS) (EPS) of $1.92, the question arises: is the stock significantly overvalued? This article aims to provide a detailed valuation analysis of NVIDIA, offering insights into its financial strength, profitability, growth, and more. We invite you to delve into this comprehensive analysis.\n\nCompany Overview\nWarning! GuruFocus has detected 10 Warning Signs with NVDA. Click here to check it out.\n\nNVDA 30-Year Financial Data\n\nThe intrinsic value of NVDA\n\n\nNVIDIA Corp (NASDAQ:NVDA) is a leading designer of discrete graphics processing units that enhance the experience on computing platforms. The firm's chips are widely used in various end markets, including PC gaming and data centers. In recent years, NVIDIA has broadened its focus from traditional PC graphics applications such as gaming to more complex and favorable opportunities, including artificial intelligence and autonomous driving, leveraging the high-performance capabilities of its products.\n\nCurrently, NVIDIA's stock price stands at $418.01, significantly higher than the GF Value of $310.28, indicating the stock might be overvalued. With a market cap of $1 trillion, the valuation seems steep. The following analysis aims to delve deeper into the company's value.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nUnderstanding the GF Value\nThe GF Value is a unique measure of the intrinsic value of a stock, calculated based on historical trading multiples, a GuruFocus adjustment factor, and future business performance estimates. If the stock price is significantly above the GF Value Line, it is overvalued, and its future return is likely to be poor. Conversely, if it is significantly below the GF Value Line, its future return will likely be higher.\n\nAccording to GuruFocus Value calculation, NVIDIA (NASDAQ:NVDA) appears to be significantly overvalued. The stock's current price of $418.01 per share and the market cap of $1 trillion further strengthen this assumption.\n\nGiven that NVIDIA is significantly overvalued, the long-term return of its stock is likely to be much lower than its future business growth.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nLink: These companies may deliver higher future returns at reduced risk.\n\nFinancial Strength of NVIDIA\nExamining the financial strength of a company is crucial before investing in its stock. Companies with poor financial strength pose a higher risk of permanent loss. NVIDIA's cash-to-debt ratio of 1.27 is worse than 58.04% of companies in the Semiconductors industry. However, NVIDIA's overall financial strength is 8 out of 10, indicating a strong financial position.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nProfitability and Growth\nConsistent profitability over the long term reduces the risk for investors. NVIDIA, with its profitability ranking of 10 out of 10, has been profitable for the past 10 years. The company's operating margin of 17.37% ranks better than 76.5% of companies in the Semiconductors industry.\n\nHowever, growth is a crucial factor in a company's valuation. NVIDIA's growth ranks worse than 52.99% of companies in the Semiconductors industry, with its 3-year average revenue growth rate better than 87.88% of companies in the industry.\n\nROIC vs WACC\nComparing a company's return on invested capital (ROIC) to its weighted average cost of capital (WACC) is an effective way to evaluate its profitability. Over the past 12 months, NVIDIA's ROIC was 20.32 while its WACC was 16.74, suggesting that the company is creating value fo ...

# %%
data[0].metadata
# Out:
# {'source': 'data/nvidia.txt'}

# %%
from langchain.document_loaders.csv_loader import CSVLoader
loader = CSVLoader("data/movies.csv")
movies = loader.load()

# %%
movies[0].metadata
# Out:
# {'source': 'data/movies.csv', 'row': 0}

# %%
movies[0].metadata
# Out:
# {'source': 'data/movies.csv', 'row': 0}

# %%
movies
# Out:
# [Document(metadata={'source': 'data/movies.csv', 'row': 0}, page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR'),
#  Document(metadata={'source': 'data/movies.csv', 'row': 1}, page_content='movie_id: 102\ntitle: Doctor Strange in the Multiverse of Madness\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 7\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 200\nrevenue: 954.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'data/movies.csv', 'row': 2}, page_content='movie_id: 103\ntitle: Thor: The Dark World\nindustry: Hollywood\nrelease_year: 2013\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 165\nrevenue: 644.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'data/movies.csv', 'row': 3}, page_content='movie_id: 104\ntitle: Thor: Ragnarok\nindustry: Hollywood\nrelease_year: 2017\nimdb_rating: 7.9\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 180\nrevenue: 854\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'data/movies.csv', 'row': 4}, page_content='movie_id: 105\ntitle: Thor: Love and Thunder\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 250\nrevenue: 670\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'data/movies.csv', 'row': 5}, page_content='movie_id: 106\ntitle: Sholay\nindustry: Bollywood\nrelease_year: 1975\nimdb_rating: 8.1\nstudio: United Producers\nlanguage_id: 1\nbudget: Not Available\nrevenue: Not Available\nunit: Not Available\ncurrency: Not Available'),
#  Document(metadata={'source': 'data/movies.csv', 'row': 6}, page_content='movie_id: 107\ntitle: Dilwale Dulhania Le Jayenge\nindustry: Bollywood\nrelease_year: 1995\nimdb_rating: 8\nstudio: Yash Raj Films\nlanguage_id: 1\nbudget: 400\nrevenue: 2000\nunit: Millions\ncurrency: INR'),
#  Document(metadata={'source': 'data/movies.csv', 'row': 7}, page_content='movie_id: 108\ntitle: 3 Idiots\nindustry: Bollywood\nrelease_year: 2009\nimdb_rating: 8.4\nstudio: Vinod Chopra Films\nlanguage_id: 1\nbudget: 550\nrevenue: 4000\nunit: Millions\ncurrency: INR'),
#  Document(metadata={'source': 'data/movies.csv', 'row': 8}, page_content='movie_id: 109\ntitle: Kabhi Khushi Kabhie Gham\nindustry: Bollywood\nrelease_year: 2001\nimdb_rating: 7.4\nstudio: Dharma Productions\nlanguage_id: 1\nbudget: 390\nrevenue: 1360\nunit: Millions\ncurrency: INR')]

# %%
from langchain.document_loaders import UnstructuredURLLoader

# %%
pip install unstructured libmagic python-magic python-magic-bin
# Out:
# Collecting unstructured
#   Downloading unstructured-0.18.32-py3-none-any.whl.metadata (25 kB)
# Collecting libmagic
#   Downloading libmagic-1.0.tar.gz (3.7 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting python-magic
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting python-magic-bin
#   Downloading python_magic_bin-0.4.14-py2.py3-none-win_amd64.whl.metadata (710 bytes)
# Requirement already satisfied: charset-normalizer in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured) (3.4.4)
# Requirement already satisfied: filetype in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured) (1.2.0)
# Collecting lxml (from unstructured)
#   Downloading lxml-6.0.2-cp314-cp314-win_amd64.whl.metadata (3.7 kB)
# Collecting nltk (from unstructured)
#   Downloading nltk-3.9.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured) (2.32.5)
# Collecting beautifulsoup4 (from unstructured)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2026.1.31-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------------------------------------- 981.5/981.5 kB 11.5 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured) (2.4.2)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.14.3-cp314-cp314-win_amd64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured) (4.15.0)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.42.10-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured) (2.1.1)
# Requirement already satisfied: tqdm in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured) (4.67.3)
# Requirement already satisfied: psutil in C:\Users\dheekonda.srinivasar\AppData\Roaming\Python\Python314\site-packages (from unstructured) (7.2.2)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting numba (from unstructured)
#   Downloading numba-0.64.0-cp314-cp314-win_amd64.whl.metadata (3.0 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->unstructured)
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dataclasses-json->unstructured) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: six>=1.9 in C:\Users\dheekonda.srinivasar\AppData\Roaming\Python\Python314\site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk->unstructured) (8.3.1)
# Requirement already satisfied: joblib in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk->unstructured) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk->unstructured) (2026.2.28)
# Requirement already satisfied: colorama in C:\Users\dheekonda.srinivasar\AppData\Roaming\Python\Python314\site-packages (from click->nltk->unstructured) (0.4.6)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba->unstructured)
#   Downloading llvmlite-0.46.0-cp314-cp314-win_amd64.whl.metadata (5.1 kB)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->unstructured) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->unstructured) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->unstructured) (2026.1.4)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Downloading aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: cryptography>=3.1 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured-client->unstructured) (46.0.5)
# Requirement already satisfied: httpcore>=1.0.9 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured-client->unstructured) (2.12.5)
# Collecting pypdf>=6.2.0 (from unstructured-client->unstructured)
#   Downloading pypdf-6.9.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pypdfium2>=5.0.0 (from unstructured-client->unstructured)
#   Downloading pypdfium2-5.6.0-py3-none-win_amd64.whl.metadata (68 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi>=2.0.0->cryptography>=3.1->unstructured-client->unstructured) (3.0)
# Requirement already satisfied: h11>=0.16 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.12.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.2)
# Downloading unstructured-0.18.32-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 16.5 MB/s  0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_magic_bin-0.4.14-py2.py3-none-win_amd64.whl (409 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ---------------------------------------- 0.0/608.4 kB ? eta -:--:--
#    ---------------------------------------- 608.4/608.4 kB 14.0 MB/s  0:00:00
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading lxml-6.0.2-cp314-cp314-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ------------------------- -------------- 2.6/4.1 MB 33.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 12.5 MB/s  0:00:00
# Downloading nltk-3.9.3-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 23.3 MB/s  0:00:00
# Downloading numba-0.64.0-cp314-cp314-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 2.8/2.8 MB 16.2 MB/s  0:00:00
# Downloading llvmlite-0.46.0-cp314-cp314-win_amd64.whl (39.2 MB)
#    ---------------------------------------- 0.0/39.2 MB ? eta -:--:--
#    ------- -------------------------------- 7.1/39.2 MB 38.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 11.3/39.2 MB 26.8 MB/s eta 0:00:02
#    -------------- ------------------------- 14.7/39.2 MB 25.5 MB/s eta 0:00:01
#    ------------------ --------------------- 18.1/39.2 MB 23.7 MB/s eta 0:00:01
#    --------------------- ------------------ 21.5/39.2 MB 20.7 MB/s eta 0:00:01
#    ------------------------ --------------- 23.6/39.2 MB 19.6 MB/s eta 0:00:01
#    -------------------------- ------------- 26.2/39.2 MB 18.3 MB/s eta 0:00:01
#    --------------------------- ------------ 26.7/39.2 MB 18.1 MB/s eta 0:00:01
#    --------------------------- ------------ 26.7/39.2 MB 18.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 28.0/39.2 MB 13.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 29.4/39.2 MB 13.4 MB/s eta 0:00:01
#    -------------------------------- ------- 32.2/39.2 MB 13.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.9/39.2 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  38.3/39.2 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------  39.1/39.2 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 39.2/39.2 MB 12.5 MB/s  0:00:03
# Downloading python_iso639-2026.1.31-py3-none-any.whl (167 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading rapidfuzz-3.14.3-cp314-cp314-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 13.3 MB/s  0:00:00
# Downloading unstructured_client-0.42.10-py3-none-any.whl (220 kB)
# Downloading aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Downloading pypdf-6.9.1-py3-none-any.whl (333 kB)
# Downloading pypdfium2-5.6.0-py3-none-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ---------------------------------------  3.7/3.7 MB 17.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 15.7 MB/s  0:00:00
# Building wheels for collected packages: libmagic, langdetect
#   Building wheel for libmagic (pyproject.toml): started
#   Building wheel for libmagic (pyproject.toml): finished with status 'done'
#   Created wheel for libmagic: filename=libmagic-1.0-py3-none-any.whl size=4325 sha256=493a99b2756200a483ab892de040b01458d9e50408518f404144460f0c12d444
#   Stored in directory: c:\users\dheekonda.srinivasar\appdata\local\pip\cache\wheels\27\cb\60\f3e7ff506e66cfea6d265d12df06319c85a9ce620c42feff42
#   Building wheel for langdetect (pyproject.toml): started
#   Building wheel for langdetect (pyproject.toml): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=1019155 sha256=aef33e953bf6324571baa014fb63e6b83499daacd58fcc0895edf90875526d7c
#   Stored in directory: c:\users\dheekonda.srinivasar\appdata\local\pip\cache\wheels\13\60\5a\f2012969b3f7413b62b7b7063d6c9b45c93004a978cbe8ea2f
# Successfully built libmagic langdetect
# Installing collected packages: python-magic-bin, libmagic, soupsieve, rapidfuzz, python-magic, python-iso639, pypdfium2, pypdf, olefile, lxml, llvmlite, langdetect, html5lib, emoji, backoff, aiofiles, python-oxmsg, numba, nltk, beautifulsoup4, unstructured-client, unstructured
#
#    --- ------------------------------------  2/22 [soupsieve]
#    --- ------------------------------------  2/22 [soupsieve]
#    ----- ----------------------------------  3/22 [rapidfuzz]
#    ----- ----------------------------------  3/22 [rapidfuzz]
#    ----- ----------------------------------  3/22 [rapidfuzz]
#    ----- ----------------------------------  3/22 [rapidfuzz]
#    ----- ----------------------------------  3/22 [rapidfuzz]
#    ----- ----------------------------------  3/22 [rapidfuzz]
#    --------- ------------------------------  5/22 [python-iso639]
#    ---------- -----------------------------  6/22 [pypdfium2]
#    ---------- -----------------------------  6/22 [pypdfium2]
#    ---------- -----------------------------  6/22 [pypdfium2]
#    ---------- -----------------------------  6/22 [pypdfium2]
#    ---------- -----------------------------  6/22 [pypdfium2]
#   Attempting uninstall: pypdf
#    ---------- -----------------------------  6/22 [pypdfium2]
#     Found existing installation: pypdf 5.6.1
#    ---------- -----------------------------  6/22 [pypdfium2]
#     Uninstalling pypdf-5.6.1:
#    ---------- -----------------------------  6/22 [pypdfium2]
#       Successfully uninstalled pypdf-5.6.1
#    ---------- -----------------------------  6/22 [pypdfium2]
#    ------------ ---------------------------  7/22 [pypdf]
#    ------------ ---------------------------  7/22 [pypdf]
#    ------------ ---------------------------  7/22 [pypdf]
#    ------------ ---------------------------  7/22 [pypdf]
#    ------------ ---------------------------  7/22 [pypdf]
#    ------------ ---------------------------  7/22 [pypdf]
#    ------------ ---------------------------  7/22 [pypdf]
#    ------------ ---------------------------  7/22 [pypdf]
#    ---------------- -----------------------  9/22 [lxml]
#    ---------------- -----------------------  9/22 [lxml]
#    ---------------- -----------------------  9/22 [lxml]
#    ---------------- -----------------------  9/22 [lxml]
#    ---------------- -----------------------  9/22 [lxml]
#    ------------------ --------------------- 10/22 [llvmlite]
#    ------------------ --------------------- 10/22 [llvmlite]
#    ------------------ --------------------- 10/22 [llvmlite]
#    ------------------ --------------------- 10/22 [llvmlite]
#    ------------------ --------------------- 10/22 [llvmlite]
#    ------------------ --------------------- 10/22 [llvmlite]
#    ------------------ --------------------- 10/22 [llvmlite]
#    -------------------- ------------------- 11/22 [langdetect]
#    -------------------- ------------------- 11/22 [langdetect]
#    --------------------- ------------------ 12/22 [html5lib]
#    --------------------- ------------------ 12/22 [html5lib]
#    --------------------- ------------------ 12/22 [html5lib]
#    --------------------- ------------------ 12/22 [html5lib]
#    ----------------------- ---------------- 13/22 [emoji]
#    ------------------------- -------------- 14/22 [backoff]
#    --------------------------- ------------ 15/22 [aiofiles]
#    ----------------------------- ---------- 16/22 [python-oxmsg]
#    ----------------------------- ---------- 16/22 [python-oxmsg]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    ------------------------------ --------- 17/22 [numba]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    -------------------------------- ------- 18/22 [nltk]
#    ---------------------------------- ----- 19/22 [beautifulsoup4]
#    ---------------------------------- ----- 19/22 [beautifulsoup4]
#    ---------------------------------- ----- 19/22 [beautifulsoup4]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    ------------------------------------ --- 20/22 [unstructured-client]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    -------------------------------------- - 21/22 [unstructured]
#    ---------------------------------------- 22/22 [unstructured]
#
# Successfully installed aiofiles-25.1.0 backoff-2.2.1 beautifulsoup4-4.14.3 emoji-2.15.0 html5lib-1.1 langdetect-1.0.9 libmagic-1.0 llvmlite-0.46.0 lxml-6.0.2 nltk-3.9.3 numba-0.64.0 olefile-0.47 pypdf-6.9.1 pypdfium2-5.6.0 python-iso639-2026.1.31 python-magic-0.4.27 python-magic-bin-0.4.14 python-oxmsg-0.0.2 rapidfuzz-3.14.3 soupsieve-2.8.3 unstructured-0.18.32 unstructured-client-0.42.10
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script pypdfium2.exe is installed in 'c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script oxmsg.exe is installed in 'c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
loader = UnstructuredURLLoader(urls=[
     "https://www.moneycontrol.com/news/business/banks/hdfc-bank-re-appoints-sanmoy-chakrabarti-as-chief-risk-officer-11259771.html",
     "https://www.moneycontrol.com/news/business/markets/market-corrects-post-rbi-ups-inflation-forecast-icrr-bet-on-these-top-10-rate-sensitive-stocks-ideas-11142611.html"
    
])

data = loader.load()

# %%
len(data)
# Out:
# 2

# %% [markdown]
# ### Text Splitters
# Why do we need text splitters in first place?
#
# LLM's have token limits. Hence we need to split the text which can be large into small chunks so that each chunk size is under the token limit. There are various text splitter classes in langchain that allows us to do this.

# %%
##Taking some random text from wikipedia

text = """Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. 
It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. 
Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.

Brothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg. 
Kip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar. 
Cinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles. 
Interstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.

Interstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. 
It has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades."""

# %%
text[:200]
# Out:
# 'Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Mat'

# %%
chunks =[]
s = ""
for word in text:
    s +=word + ""
    if len(s)>200:
        chunks.append(s)
        s=""
chunks.append(s)

# %%
chunks
# Out:
# ['Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt',
#  ' Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn i',
#  'n search of a new home for humankind.\n\nBrothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed b',
#  'y Steven Spielberg. \nKip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science',
#  ' of Interstellar. \nCinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, ',
#  'Iceland, and Los Angeles. \nInterstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.\n\nInterstellar premiered in Los Angeles on Oct',
#  'ober 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 m',
#  'illion worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. \nIt has been praised by astronomers for its scientific accuracy and portrayal of theoret',
#  'ical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades.']

# %%
from langchain.text_splitter import CharacterTextSplitter
splitter = CharacterTextSplitter(
    separator="\n",
    chunk_size = 200,
    chunk_overlap = 0
)

chunks = splitter.split_text(text)
len(chunks)
# Out:
# Created a chunk of size 210, which is longer than the specified 200
# Created a chunk of size 208, which is longer than the specified 200
# Created a chunk of size 358, which is longer than the specified 200
# 9

# %%
for chunk in chunks:
    print(len(chunk))
# Out:
# 105
# 120
# 210
# 181
# 197
# 207
# 128
# 357
# 253

# %%
chunks
# Out:
# ['Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan.',
#  'It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine.',
#  'Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.',
#  'Brothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg.',
#  'Kip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar.',
#  'Cinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles.',
#  'Interstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.',
#  'Interstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014.',
#  'It has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades.']

# %%
from langchain.text_splitter import CharacterTextSplitter
splitter = CharacterTextSplitter(
    separator=".",
    chunk_size = 200,
    chunk_overlap = 0
)

chunks = splitter.split_text(text)
len(chunks)
# Out:
# Created a chunk of size 211, which is longer than the specified 200
# 12

# %%
for chunk in chunks:
    print(len(chunk))
# Out:
# 104
# 119
# 209
# 180
# 196
# 112
# 92
# 187
# 103
# 192
# 104
# 147

# %% [markdown]
# As you can see, all though we gave 200 as a chunk size since the split was based on \n, it ended up creating chunks that are bigger than size 200.
#
# Another class from Langchain can be used to recursively split the text based on a list of separators. This class is RecursiveTextSplitter. Let's see how it works

# %% [markdown]
# ### RecursiveTextSplitter

# %%
text
# Out:
# 'Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.\n\nBrothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg. \nKip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar. \nCinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles. \nInterstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.\n\nInterstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. \nIt has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades.'

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
r_splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n","\n"," ","."],
    chunk_size = 200,
    chunk_overlap = 0
)

# %%
chunks =  r_splitter.split_text(text)

# %%
for chunk in chunks:
    print(len(chunk))
# Out:
# 105
# 120
# 199
# 10
# 181
# 197
# 198
# 8
# 128
# 191
# 165
# 198
# 54
