# %%
import pandas as pd
pd.set_option('display.max_colwidth',100)

# %%
df = pd.read_csv('data/sample_text.csv')

# %%
df.shape
# Out:
# (8, 2)

# %%
from sentence_transformers import SentenceTransformer

# %%
encoder = SentenceTransformer("all-mpnet-base-v2")
# Out:
# c:\Users\dheekonda.srinivasar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\dheekonda.srinivasar\.cache\huggingface\hub\models--sentence-transformers--all-mpnet-base-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
vectors = encoder.encode(df.text)

# %%
vectors.shape
# Out:
# (8, 768)

# %%
vectors
# Out:
# array([[-0.00247396,  0.03626723, -0.05290461, ..., -0.09152357,
#         -0.03969999, -0.04330489],
#        [-0.03357267,  0.00980516, -0.03250129, ..., -0.05165466,
#          0.02245891, -0.03156184],
#        [-0.01865321, -0.04051318, -0.01235387, ...,  0.00610587,
#         -0.07179647,  0.0277385 ],
#        ...,
#        [-0.00066459,  0.04252131, -0.05645508, ...,  0.01315469,
#         -0.03183568, -0.04357663],
#        [-0.03317154,  0.03252455, -0.02484839, ...,  0.01174421,
#          0.05747124,  0.00571022],
#        [-0.00166394,  0.00413826, -0.04597082, ...,  0.02008526,
#          0.0565624 , -0.00161595]], shape=(8, 768), dtype=float32)

# %%
dim = vectors.shape[1]
dim
# Out:
# 768

# %%
import faiss 
index=faiss.IndexFlatL2(dim) #euclidean distance or L2 distance
index
##here I am creating an index of 768 (len of vector)
# Out:
# <faiss.swigfaiss_avx2.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x000001F467F8D9E0> >

# %%
index.add(vectors)

# %%
search_query = " A apple a day keeps doctor away"
vec = encoder.encode(search_query)
vec.shape
# Out:
# (768,)

# %%
## here we have one dimentional array but we need 2 dimentional array 
import numpy as np
svec = np.array(vec).reshape(1,-1)
svec.shape
# Out:
# (1, 768)

# %%
distance , I = index.search(svec,k=2)

# %%
I
# Out:
# array([[1, 0]])

# %%
df.loc[[1, 0]]
# Out:
#                                                                text category
# 1  Fruits, whole grains and vegetables helps control blood pressure   Health
# 0                     Meditation and yoga can improve mental health   Health
